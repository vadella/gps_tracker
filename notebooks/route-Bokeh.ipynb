# %%
from bokeh.plotting import show, output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a02a720d-8b87-426a-ba9b-068eed074695">Loading BokehJS ...</span>
#     </div>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %autoreload 2
from my_gps_tracker import MyFitFileBase, MyFitFileTrack, MyFitFileTrackMap

# %%
data_file1 = '../data/20180311 toertocht bertem.fit'

# %%
m = MyFitFileTrackMap(data_file1)

# %%
plots = m.plots(subjects=('speed',), include_map=False)
show(plots)

# %%
plots = m.plots(x_label='distance', subjects=('speed',), include_map=False)
show(plots)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="647addf8-3f56-4ff7-9fab-219a6ea5c81e"></div>
# </div>

# %%
show(m.route_map())
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="596d564e-6000-4838-8186-b0ccffa15026"></div>
# </div>

# %%
show(m.plots())
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="139034ec-3d44-4f51-aa86-18699cf89832"></div>
# </div>
